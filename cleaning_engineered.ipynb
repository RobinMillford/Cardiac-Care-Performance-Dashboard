# %%
import pandas as pd

# %%
df = pd.read_csv('Cardiac_Surgery_and_Percutaneous_Coronary_Interventions_by_Hospital___Beginning_2008_20250726.csv')
df.head(10)
# Out:
#    Facility ID           Hospital Name          Detailed Region  \
# 0            1         Albany Med. Ctr         Capital District
# 1         1045   White Plains Hospital  NY Metro - New Rochelle
# 2         1438   Bellevue Hospital Ctr                Manhattan
# 3         1439     Beth Israel Med Ctr                Manhattan
# 4         1178  Bronx-Lebanon-Cncourse                    Bronx
# 5         1286  Brookdale Hosp Med Ctr                    Kings
# 6          116     Arnot Ogden Med Ctr   Western NY - Rochester
# 7          746  Bassett Medical Center         Capital District
# 8         1456    Mount Sinai Hospital                Manhattan
# 9         1438   Bellevue Hospital Ctr                Manhattan
#
#                     Region            Procedure Year of Hospital Discharge  \
# 0         Capital District              All PCI                       2016
# 1  NY Metro - New Rochelle    Non-Emergency PCI                       2015
# 2           NY Metro - NYC              All PCI                       2010
# 3           NY Metro - NYC              All PCI                       2010
# 4           NY Metro - NYC              All PCI                       2010
# 5           NY Metro - NYC              All PCI                       2010
# 6   Western NY - Rochester              All PCI                       2016
# 7         Capital District              All PCI                       2016
# 8           NY Metro - NYC  Valve or Valve/CABG                  2013-2015
# 9           NY Metro - NYC              All PCI                       2016
#
#    Number of Cases  Number of Deaths  Observed Mortality Rate  \
# 0              680                17                     2.50
# 1              338                 1                     0.30
# 2              448                 4                     0.89
# 3             1762                11                     0.62
# 4               65                 4                     6.15
# 5              338                 9                     2.66
# 6              306                 3                     0.98
# 7              570                 8                     1.40
# 8             2151                51                     2.37
# 9              456                 7                     1.54
#
#    Expected Mortality Rate  Risk-Adjusted Mortality Rate  \
# 0                     1.52                          2.03
# 1                     0.64                          0.34
# 2                     0.89                          0.84
# 3                     0.70                          0.75
# 4                     2.41                          2.15
# 5                     1.36                          1.65
# 6                     1.80                          0.68
# 7                     1.09                          1.59
# 8                     3.09                          2.33
# 9                     1.70                          1.12
#
#    Lower Limit of Confidence Interval  Upper Limit of Confidence Interval  \
# 0                                1.18                                3.26
# 1                                0.00                                1.91
# 2                                0.23                                2.16
# 3                                0.38                                1.35
# 4                                0.58                                5.50
# 5                                0.75                                3.13
# 6                                0.14                                1.97
# 7                                0.68                                3.13
# 8                                1.73                                3.06
# 9                                0.45                                2.31
#
#                        Comparison Results
# 0  Rate not different than Statewide Rate
# 1  Rate not different than Statewide Rate
# 2  Rate not different than Statewide Rate
# 3  Rate not different than Statewide Rate
# 4  Rate not different than Statewide Rate
# 5  Rate not different than Statewide Rate
# 6  Rate not different than Statewide Rate
# 7  Rate not different than Statewide Rate
# 8  Rate not different than Statewide Rate
# 9  Rate not different than Statewide Rate

# %%
# Display initial info to understand data types and missing values
print("--- Initial DataFrame Info ---")
df.info()
print("\n--- Initial Head ---")
print(df.head())

# --- 2. Data Cleaning and Type Conversion ---

# Clean column names: remove leading/trailing spaces, replace spaces with underscores
df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('/', '_').str.replace('-', '_')

# Convert relevant columns to numeric types
numeric_cols = [
    'Facility_ID', 'Number_of_Cases', 'Number_of_Deaths',
    'Observed_Mortality_Rate', 'Expected_Mortality_Rate', 'Risk_Adjusted_Mortality_Rate',
    'Lower_Limit_of_Confidence_Interval', 'Upper_Limit_of_Confidence_Interval'
]
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Check for missing values after initial conversion
print("\n--- Missing Values After Numeric Conversion ---")
print(df.isnull().sum())

def parse_year_range(year_str):
    if pd.isna(year_str):
        return None, None # Handle NaN values
    year_str = str(year_str).strip() # Ensure it's a string and strip whitespace
    if '-' in year_str:
        parts = year_str.split('-')
        try:
            start = int(parts[0])
            end = int(parts[1])
            return start, end
        except ValueError:
            # Handle cases where parts might not be valid integers if data is messy
            return None, None
    else:
        try:
            single_year = int(year_str)
            return single_year, single_year # If it's a single year, start and end are the same
        except ValueError:
            return None, None

# Apply the function to create 'Start_Year' and 'End_Year'
df[['Start_Year', 'End_Year']] = df['Year_of_Hospital_Discharge'].apply(lambda x: pd.Series(parse_year_range(x)))

# For most trending and analysis, using the 'Start_Year' is a practical approach.
df['Mid_Year'] = ((df['Start_Year'] + df['End_Year']) / 2).astype('Int64') # Using Int64 to allow NaN

# --- 4. Feature Engineering: Mortality Flags / Categories ---

# Create a categorical column for 'Comparison_Results'
df['Comparison_Results_Category'] = df['Comparison_Results'].astype('category')

# Create a boolean flag for "Higher than Expected" mortality
df['Is_Higher_Than_Expected_Mortality'] = (df['Comparison_Results'] == 'Rate higher than Statewide Rate')

# Create a boolean flag for "Lower than Expected" mortality
df['Is_Lower_Than_Expected_Mortality'] = (df['Comparison_Results'] == 'Rate lower than Statewide Rate')

# Create a flag for "Not Different from Expected"
df['Is_As_Expected_Mortality'] = (df['Comparison_Results'] == 'Rate not different than Statewide Rate')


# --- 5. Feature Engineering: Rate Differences (useful for analysis) ---

# Difference between Observed and Expected Mortality
df['Observed_vs_Expected_Difference'] = df['Observed_Mortality_Rate'] - df['Expected_Mortality_Rate']

# Difference between Observed and Risk-Adjusted Mortality (if different definitions apply)
df['Observed_vs_RiskAdjusted_Difference'] = df['Observed_Mortality_Rate'] - df['Risk_Adjusted_Mortality_Rate']

# --- 6. Review Final DataFrame ---
print("\n--- Final DataFrame Info After Cleaning and Feature Engineering ---")
df.info()
print("\n--- Final Head with New Columns ---")
print(df.head())
print("\n--- Check Year Range Handling ---")
print(df[['Year_of_Hospital_Discharge', 'Start_Year', 'End_Year', 'Mid_Year']].head(10))

# --- 7. Save Cleaned Data ---
# df.to_csv('cardiac_data_cleaned_engineered.csv', index=False)
# print("\nCleaned and engineered data saved to 'cardiac_data_cleaned_engineered.csv'")
# Out:
# --- Initial DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2812 entries, 0 to 2811
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Facility ID                         2812 non-null   int64
#  1   Hospital Name                       2812 non-null   object
#  2   Detailed Region                     2812 non-null   object
#  3   Region                              2812 non-null   object
#  4   Procedure                           2812 non-null   object
#  5   Year of Hospital Discharge          2812 non-null   object
#  6   Number of Cases                     2812 non-null   int64
#  7   Number of Deaths                    2812 non-null   int64
#  8   Observed Mortality Rate             2812 non-null   float64
#  9   Expected Mortality Rate             2812 non-null   float64
#  10  Risk-Adjusted Mortality Rate        2812 non-null   float64
#  11  Lower Limit of Confidence Interval  2757 non-null   float64
#  12  Upper Limit of Confidence Interval  2757 non-null   float64
#  13  Comparison Results                  2812 non-null   object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 307.7+ KB
#
# --- Initial Head ---
#    Facility ID           Hospital Name          Detailed Region  \
# 0            1         Albany Med. Ctr         Capital District
# 1         1045   White Plains Hospital  NY Metro - New Rochelle
# 2         1438   Bellevue Hospital Ctr                Manhattan
# 3         1439     Beth Israel Med Ctr                Manhattan
# 4         1178  Bronx-Lebanon-Cncourse                    Bronx
#
#                     Region          Procedure Year of Hospital Discharge  \
# 0         Capital District            All PCI                       2016
# 1  NY Metro - New Rochelle  Non-Emergency PCI                       2015
# 2           NY Metro - NYC            All PCI                       2010
# 3           NY Metro - NYC            All PCI                       2010
# 4           NY Metro - NYC            All PCI                       2010
#
#    Number of Cases  Number of Deaths  Observed Mortality Rate  \
# 0              680                17                     2.50
# 1              338                 1                     0.30
# 2              448                 4                     0.89
# 3             1762                11                     0.62
# 4               65                 4                     6.15
#
#    Expected Mortality Rate  Risk-Adjusted Mortality Rate  \
# 0                     1.52                          2.03
# 1                     0.64                          0.34
# 2                     0.89                          0.84
# 3                     0.70                          0.75
# 4                     2.41                          2.15
#
#    Lower Limit of Confidence Interval  Upper Limit of Confidence Interval  \
# 0                                1.18                                3.26
# 1                                0.00                                1.91
# 2                                0.23                                2.16
# 3                                0.38                                1.35
# 4                                0.58                                5.50
#
#                        Comparison Results
# 0  Rate not different than Statewide Rate
# 1  Rate not different than Statewide Rate
# 2  Rate not different than Statewide Rate
# 3  Rate not different than Statewide Rate
# 4  Rate not different than Statewide Rate
#
# --- Missing Values After Numeric Conversion ---
# Facility_ID                            0
# Hospital_Name                          0
# Detailed_Region                        0
# Region                                 0
# Procedure                              0
# Year_of_Hospital_Discharge             0
# Number_of_Cases                        0
# Number_of_Deaths                       0
# Observed_Mortality_Rate                0
# Expected_Mortality_Rate                0
# Risk_Adjusted_Mortality_Rate           0
# Lower_Limit_of_Confidence_Interval    55
# Upper_Limit_of_Confidence_Interval    55
# Comparison_Results                     0
# dtype: int64
#
# --- Final DataFrame Info After Cleaning and Feature Engineering ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2812 entries, 0 to 2811
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Facility_ID                          2812 non-null   int64
#  1   Hospital_Name                        2812 non-null   object
#  2   Detailed_Region                      2812 non-null   object
#  3   Region                               2812 non-null   object
#  4   Procedure                            2812 non-null   object
#  5   Year_of_Hospital_Discharge           2812 non-null   object
#  6   Number_of_Cases                      2812 non-null   int64
#  7   Number_of_Deaths                     2812 non-null   int64
#  8   Observed_Mortality_Rate              2812 non-null   float64
#  9   Expected_Mortality_Rate              2812 non-null   float64
#  10  Risk_Adjusted_Mortality_Rate         2812 non-null   float64
#  11  Lower_Limit_of_Confidence_Interval   2757 non-null   float64
#  12  Upper_Limit_of_Confidence_Interval   2757 non-null   float64
#  13  Comparison_Results                   2812 non-null   object
#  14  Start_Year                           2812 non-null   int64
#  15  End_Year                             2812 non-null   int64
#  16  Mid_Year                             2812 non-null   Int64
#  17  Comparison_Results_Category          2812 non-null   category
#  18  Is_Higher_Than_Expected_Mortality    2812 non-null   bool
#  19  Is_Lower_Than_Expected_Mortality     2812 non-null   bool
#  20  Is_As_Expected_Mortality             2812 non-null   bool
#  21  Observed_vs_Expected_Difference      2812 non-null   float64
#  22  Observed_vs_RiskAdjusted_Difference  2812 non-null   float64
# dtypes: Int64(1), bool(3), category(1), float64(7), int64(5), object(6)
# memory usage: 431.5+ KB
#
# --- Final Head with New Columns ---
#    Facility_ID           Hospital_Name          Detailed_Region  \
# 0            1         Albany Med. Ctr         Capital District
# 1         1045   White Plains Hospital  NY Metro - New Rochelle
# 2         1438   Bellevue Hospital Ctr                Manhattan
# 3         1439     Beth Israel Med Ctr                Manhattan
# 4         1178  Bronx-Lebanon-Cncourse                    Bronx
#
#                     Region          Procedure Year_of_Hospital_Discharge  \
# 0         Capital District            All PCI                       2016
# 1  NY Metro - New Rochelle  Non-Emergency PCI                       2015
# 2           NY Metro - NYC            All PCI                       2010
# 3           NY Metro - NYC            All PCI                       2010
# 4           NY Metro - NYC            All PCI                       2010
#
#    Number_of_Cases  Number_of_Deaths  Observed_Mortality_Rate  \
# 0              680                17                     2.50
# 1              338                 1                     0.30
# 2              448                 4                     0.89
# 3             1762                11                     0.62
# 4               65                 4                     6.15
#
#    Expected_Mortality_Rate  ...                      Comparison_Results  \
# 0                     1.52  ...  Rate not different than Statewide Rate
# 1                     0.64  ...  Rate not different than Statewide Rate
# 2                     0.89  ...  Rate not different than Statewide Rate
# 3                     0.70  ...  Rate not different than Statewide Rate
# 4                     2.41  ...  Rate not different than Statewide Rate
#
#    Start_Year  End_Year Mid_Year             Comparison_Results_Category  \
# 0        2016      2016     2016  Rate not different than Statewide Rate
# 1        2015      2015     2015  Rate not different than Statewide Rate
# 2        2010      2010     2010  Rate not different than Statewide Rate
# 3        2010      2010     2010  Rate not different than Statewide Rate
# 4        2010      2010     2010  Rate not different than Statewide Rate
#
#    Is_Higher_Than_Expected_Mortality  Is_Lower_Than_Expected_Mortality  \
# 0                              False                             False
# 1                              False                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
#
#   Is_As_Expected_Mortality  Observed_vs_Expected_Difference  \
# 0                     True                             0.98
# 1                     True                            -0.34
# 2                     True                             0.00
# 3                     True                            -0.08
# 4                     True                             3.74
#
#    Observed_vs_RiskAdjusted_Difference
# 0                                 0.47
# 1                                -0.04
# 2                                 0.05
# 3                                -0.13
# 4                                 4.00
#
# [5 rows x 23 columns]
#
# --- Check Year Range Handling ---
#   Year_of_Hospital_Discharge  Start_Year  End_Year  Mid_Year
# 0                       2016        2016      2016      2016
# 1                       2015        2015      2015      2015
# 2                       2010        2010      2010      2010
# 3                       2010        2010      2010      2010
# 4                       2010        2010      2010      2010
# 5                       2010        2010      2010      2010
# 6                       2016        2016      2016      2016
# 7                       2016        2016      2016      2016
# 8                  2013-2015        2013      2015      2014
# 9                       2016        2016      2016      2016

# %%
df.head()
# Out:
#    Facility_ID           Hospital_Name          Detailed_Region  \
# 0            1         Albany Med. Ctr         Capital District
# 1         1045   White Plains Hospital  NY Metro - New Rochelle
# 2         1438   Bellevue Hospital Ctr                Manhattan
# 3         1439     Beth Israel Med Ctr                Manhattan
# 4         1178  Bronx-Lebanon-Cncourse                    Bronx
#
#                     Region          Procedure Year_of_Hospital_Discharge  \
# 0         Capital District            All PCI                       2016
# 1  NY Metro - New Rochelle  Non-Emergency PCI                       2015
# 2           NY Metro - NYC            All PCI                       2010
# 3           NY Metro - NYC            All PCI                       2010
# 4           NY Metro - NYC            All PCI                       2010
#
#    Number_of_Cases  Number_of_Deaths  Observed_Mortality_Rate  \
# 0              680                17                     2.50
# 1              338                 1                     0.30
# 2              448                 4                     0.89
# 3             1762                11                     0.62
# 4               65                 4                     6.15
#
#    Expected_Mortality_Rate  ...                      Comparison_Results  \
# 0                     1.52  ...  Rate not different than Statewide Rate
# 1                     0.64  ...  Rate not different than Statewide Rate
# 2                     0.89  ...  Rate not different than Statewide Rate
# 3                     0.70  ...  Rate not different than Statewide Rate
# 4                     2.41  ...  Rate not different than Statewide Rate
#
#    Start_Year  End_Year Mid_Year             Comparison_Results_Category  \
# 0        2016      2016     2016  Rate not different than Statewide Rate
# 1        2015      2015     2015  Rate not different than Statewide Rate
# 2        2010      2010     2010  Rate not different than Statewide Rate
# 3        2010      2010     2010  Rate not different than Statewide Rate
# 4        2010      2010     2010  Rate not different than Statewide Rate
#
#    Is_Higher_Than_Expected_Mortality  Is_Lower_Than_Expected_Mortality  \
# 0                              False                             False
# 1                              False                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
#
#   Is_As_Expected_Mortality  Observed_vs_Expected_Difference  \
# 0                     True                             0.98
# 1                     True                            -0.34
# 2                     True                             0.00
# 3                     True                            -0.08
# 4                     True                             3.74
#
#    Observed_vs_RiskAdjusted_Difference
# 0                                 0.47
# 1                                -0.04
# 2                                 0.05
# 3                                -0.13
# 4                                 4.00
#
# [5 rows x 23 columns]
